# %%
import csv

def process_data_from_csv(csv_reader):
    seen_sentences = set()
    result = []

    def get_sentences(text):
        sentences = text.split('. ')
        if sentences and sentences[-1].endswith('.'):
            sentences[-1] = sentences[-1][:-1]
        return sentences

    
    next(csv_reader, None) 

    for row in csv_reader:
        num = int(row[0])  
        text = row[1]

        sentences = get_sentences(text)
        unique_sentences = []
        for sentence in sentences:
            if sentence not in seen_sentences:
                seen_sentences.add(sentence)
                unique_sentences.append(sentence)

        result.append([num, unique_sentences])

    return result
# Out:
# [[1, [' Introduction:\nVenus is one of the most famous planets in our solar system', "The planet's extreme temperature, atmospheric pressure, and volcanic activity make it a challenging place to explore", 'However, some scientists are still interested in studying Venus to learn more about its geological past and potential for extraterrestrial life', 'In this essay, I will evaluate how well the author of "The Challenge of Exploring Venus" supports the idea that studying Venus is a worthy pursuit despite the challenges it presents.\n\nBody:\nIn "The Challenge of Exploring Venus," the author, Dava Sobel, argues that studying Venus is a worthy pursuit, regardless of the dangers it presents', "Sobel describes the planet's extreme conditions and the difficulties involved in exploring it", "However, she also highlights the potential benefits of studying Venus, such as gaining insights into the geological history of Earth and other planets.\n\nThe author provides several examples of successf
# ...

# %%
import spacy
import csv

nlp = spacy.load("en_core_web_md")

def filter_atmosphere_related_sentences(data):
    filtered_data = []
    target_keywords = ['atmosphere', 'carbon dioxide', 'oxygen']
    target_tokens = [nlp(text) for text in target_keywords] 

    count = 1
    for item in data:
        num = item[0]
        sentences = item[1]
        for sentence in sentences:
            print("evaluating sentece no#",count," ...")
            count += 1
            doc = nlp(sentence)
            found = False
            for token in doc:
                for target_token in target_tokens:
                    if token.similarity(target_token) > 0.8:  
                        filtered_data.append([num, sentence])
                        found = True
                        break
                if found:
                    break
    return filtered_data

with open('/home/ahsan/Downloads/archive/Mistral7B_CME_v1.csv', 'r') as file:
    csv_reader = csv.reader(file)
    next(csv_reader)  
    data = process_data_from_csv(csv_reader)

atmosphere_data = filter_atmosphere_related_sentences(data)

with open('clean_dataset.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Text Number', 'Atmosphere Related Text'])  
    writer.writerows(atmosphere_data)

print("Data has been written to clean_dataset.csv successfully.")
# Out:
# evaluating sentece no# 1  ...
# evaluating sentece no# 2  ...
# evaluating sentece no# 3  ...
# evaluating sentece no# 4  ...
# evaluating sentece no# 5  ...
# evaluating sentece no# 6  ...
# evaluating sentece no# 7  ...
# evaluating sentece no# 8  ...
# evaluating sentece no# 9  ...
# evaluating sentece no# 10  ...
# evaluating sentece no# 11  ...
# evaluating sentece no# 12  ...
# evaluating sentece no# 13  ...
# evaluating sentece no# 14  ...
# evaluating sentece no# 15  ...
# evaluating sentece no# 16  ...
# evaluating sentece no# 17  ...
# evaluating sentece no# 18  ...
# evaluating sentece no# 19  ...
# evaluating sentece no# 20  ...
# evaluating sentece no# 21  ...
# /tmp/ipykernel_68931/2724047219.py:23: UserWarning: [W008] Evaluating Token.similarity based on empty vectors.
#   if token.similarity(target_token) > 0.8:  # Adjust the threshold based on your needs
# evaluating sentece no# 22  ...
# evaluating sentece no# 23  ...
# evaluating sentece no# 24  ...
# ...
